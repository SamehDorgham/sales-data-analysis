# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv("/content/drive/MyDrive/Intern2Grow/sales_data.csv")

# %%
data
# Out:
#            date     product     category   price  quantity  revenue
# 0    2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1    2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 2    2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0
# 3    2022-01-03  Headphones  Electronics   100.0      20.0   2000.0
# 4    2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0
# ..          ...         ...          ...     ...       ...      ...
# 364  2022-12-27       Watch  Accessories   150.0       5.0    750.0
# 365  2022-12-28        Coat     Clothing   100.0       5.0    500.0
# 366  2022-12-29  Headphones  Electronics   100.0      10.0   1000.0
# 367  2022-12-30  Smartphone  Electronics   600.0      11.0   6600.0
# 368  2022-12-31      Hoodie     Clothing    40.0      30.0   1200.0
#
# [369 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369 entries, 0 to 368
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      369 non-null    object
#  1   product   369 non-null    object
#  2   category  369 non-null    object
#  3   price     367 non-null    float64
#  4   quantity  368 non-null    float64
#  5   revenue   368 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 17.4+ KB

# %%
data.describe()
# Out:
#              price    quantity      revenue
# count   367.000000  368.000000   368.000000
# mean    211.226158   14.565217  2060.679348
# std     227.335170    8.595740  1910.930790
# min      20.000000    3.000000   300.000000
# 25%      50.000000    8.000000   800.000000
# 50%     100.000000   12.000000  1200.000000
# 75%     300.000000   20.000000  2400.000000
# max    1200.000000   50.000000  7200.000000

# %%
data.head()
# Out:
#          date     product     category   price  quantity  revenue
# 0  2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1  2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 2  2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0
# 3  2022-01-03  Headphones  Electronics   100.0      20.0   2000.0
# 4  2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0

# %%
data.tail()
# Out:
#            date     product     category  price  quantity  revenue
# 364  2022-12-27       Watch  Accessories  150.0       5.0    750.0
# 365  2022-12-28        Coat     Clothing  100.0       5.0    500.0
# 366  2022-12-29  Headphones  Electronics  100.0      10.0   1000.0
# 367  2022-12-30  Smartphone  Electronics  600.0      11.0   6600.0
# 368  2022-12-31      Hoodie     Clothing   40.0      30.0   1200.0

# %%
data.columns
# Out:
# Index(['date', 'product', 'category', 'price', 'quantity', 'revenue'], dtype='object')

# %%
data["date"] = pd.to_datetime(data["date"])
data
# Out:
#             date     product     category   price  quantity  revenue
# index
# 0     2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1     2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 2     2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0
# 3     2022-01-03  Headphones  Electronics   100.0      20.0   2000.0
# 4     2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0
# ...          ...         ...          ...     ...       ...      ...
# 364   2022-12-27       Watch  Accessories   150.0       5.0    750.0
# 365   2022-12-28        Coat     Clothing   100.0       5.0    500.0
# 366   2022-12-29  Headphones  Electronics   100.0      10.0   1000.0
# 367   2022-12-30  Smartphone  Electronics   600.0      11.0   6600.0
# 368   2022-12-31      Hoodie     Clothing    40.0      30.0   1200.0
#
# [369 rows x 6 columns]

# %% [markdown]
# ![Sales Data Analysis Dataset Meta Data.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ![Assessment questions.png](data:image/png;base64,...)

# %% [markdown]
# # **1- What was the total revenue generated by the company over the course of the year?**

# %%
TotalRevenue = data["revenue"].sum()

# %%
TotalRevenue
# Out:
# 758330.0

# %% [markdown]
# ---

# %% [markdown]
# # **2- Which product had the highest revenue? How much revenue did it generate?**

# %%
MaxProductRevenueId = data["revenue"].idxmax()
MaxProductRevenueId
# Out:
# 13

# %%
MaxProductRevenue = data["product"][MaxProductRevenueId]
MaxProductRevenue
# Out:
# 'Smartphone'

# %%
DataLength = data["revenue"].count()
DataLength = int(DataLength)
DataIndex = []
for i in range(0,DataLength+1):
  DataIndex.append(i)
data["index"] = DataIndex
data.set_index("index", inplace=True)
data
# Out:
#              date     product     category   price  quantity  revenue
# index
# 0      2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1      2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 2      2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0
# 3      2022-01-03  Headphones  Electronics   100.0      20.0   2000.0
# 4      2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0
# ...           ...         ...          ...     ...       ...      ...
# 364    2022-12-27       Watch  Accessories   150.0       5.0    750.0
# 365    2022-12-28        Coat     Clothing   100.0       5.0    500.0
# 366    2022-12-29  Headphones  Electronics   100.0      10.0   1000.0
# 367    2022-12-30  Smartphone  Electronics   600.0      11.0   6600.0
# 368    2022-12-31      Hoodie     Clothing    40.0      30.0   1200.0
#
# [369 rows x 6 columns]

# %%
MaxProductRevenueValue = data["revenue"][MaxProductRevenueId]
MaxProductRevenueValue
# Out:
# 7200.0

# %% [markdown]
# ---

# %% [markdown]
# # **3- What was the average price of a product sold by the company?**

# %%
AveragePrice = data["price"].mean()
AveragePrice.round(2)
# Out:
# 211.23

# %% [markdown]
# ---

# %% [markdown]
# # **4- What was the total quantity of products sold by the company?**

# %%
TotalQuantitySold = data["quantity"].sum()
TotalQuantitySold
# Out:
# 5360.0

# %% [markdown]
# ---

# %% [markdown]
# # **5- Which category had the highest revenue? How much revenue did it generate?**

# %%
CategoryWithHighestRevenue = data.groupby("category")["revenue"].sum()
CategoryWithHighestRevenue
# Out:
# category
# Accessories    104700.0
# Bags            19500.0
# Bgas              900.0
# Clohting         1200.0
# Clothing        94350.0
# Electronics    516080.0
# Shoes           20640.0
# Shoeses           960.0
# Name: revenue, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# # **6-What was the average revenue per sale?**

# %%
AverageRevenuePerSale = data["revenue"].mean()
AverageRevenuePerSale.round(2)
# Out:
# 2060.68

# %% [markdown]
# ---

# %% [markdown]
# # **7- What was the total revenue generated in each quarter of the year? (i.e. Q1, Q2, Q3, Q4)**

# %%
data.describe()
# Out:
#              price    quantity      revenue
# count   367.000000  368.000000   368.000000
# mean    211.226158   14.565217  2060.679348
# std     227.335170    8.595740  1910.930790
# min      20.000000    3.000000   300.000000
# 25%      50.000000    8.000000   800.000000
# 50%     100.000000   12.000000  1200.000000
# 75%     300.000000   20.000000  2400.000000
# max    1200.000000   50.000000  7200.000000

# %%
TotalQuarterRevenue = data["revenue"].groupby(data["date"].dt.quarter).sum()
TotalQuarterRevenue
# Out:
# date
# 1    182100.0
# 2    183970.0
# 3    197680.0
# 4    194580.0
# Name: revenue, dtype: float64

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# # **Data Visualization Section**

# %% [markdown]
# **1- Revenue Over Time**

# %%
X = data["date"]
Y = data["revenue"]
plt.plot(X,Y)
plt.xlabel("Date")
plt.ylabel("Revenue")
plt.title("Revenue Over Time")
plt.legend(["Revenue"])
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# **2- Category With Highest Revenue**

# %%
Category = CategoryWithHighestRevenue.index
Revenue = CategoryWithHighestRevenue.values
plt.bar(Category,Revenue)
plt.xlabel("Category")
plt.ylabel("Revenue")
plt.title("Category With Highest Revenue")
plt.legend(["Revenue"])
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# **3- Quantity Sold Over Time**

# %%
QuantitySold = data["quantity"]
Date = data["date"]
plt.bar(Date,QuantitySold)
plt.xlabel("Date")
plt.ylabel("Quantity Sold")
plt.title("Quantity Sold Over Time")
plt.legend(["Total Quantity Sold"])
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# **4- Total Quarter Revenue**

# %%
X = TotalQuarterRevenue
Y = TotalQuarterRevenue.index
plt.bar(Y,X)
plt.xlabel("Quarter")
plt.ylabel("Revenue")
plt.title("Total Quarter Revenue")
plt.legend(["Revenue"])
plt.show()

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# **... تم بحمد الله ...**
#
# **... Done by : Sameh Dorgham ...**
